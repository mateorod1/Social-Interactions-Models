# %% [markdown]
# # MIS: Clase Complementaria 13

# %% [markdown]
# La clase de hoy se dedicará a la implementación del algoritmo de Ford-Fulkerson para encontrar flujos máximos en redes. Para ello usaremos grafos dirigidos con capacidades en sus enlaces, un único nodo source "s" y un único nodo target o sink "t".

# %%
# Cargue de paquetes
import networkx as nx

# %%
# Creación del grafo con capacidades
Grafo = nx.DiGraph() # Creo el objeto grafo dirigido
Grafo.add_edges_from([('s','1'),('s','2'),('s','3'),
('1','t'),('2','t'),('3','t'),
('1','2'),('2','3')
],capacity = 3) # Creo los enlaces con capacidades default
# Cambio algunas capacidades para que el ejercicio sea interesante
Grafo.edges[('s', '2')]['capacity'] = 2
Grafo.edges[('s', '3')]['capacity'] = 1
Grafo.edges[('1', 't')]['capacity'] = 1

# %% [markdown]
# La idea de la clase es realizar la implementación con ayuda del profesor complementario y resolver dudas, principalmente aquellas relacionadas con lectura de pseudocodigo, inicialización y en general el abordaje del problema desde el punto de vista computacional. Si persisten dudas de la teoría, por favor expresenlas durante el ejercicio.

# %%
# Espacio para iniciar la implementación:
def crear_grafo_residual():
    pass
def aumentar_camino():
    pass
def ford_fulkerson():
    pass
